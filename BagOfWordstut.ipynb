# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"Datasets/spam.csv", encoding = "ISO-8859-1", engine = "python")
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
for col in ['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4']:
    df=df.drop(col,axis=1)
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.rename(columns={'v1':'Category','v2':'Message'},inplace=True)

# %%
df.Category.value_counts()
# Out:
# ham     4825
# spam     747
# Name: Category, dtype: int64

# %%
df['spam'] = df['Category'].apply(lambda x: 1 if x =='spam' else 0)

# %%
df.shape
# Out:
# (5572, 3)

# %%
df.head()
# Out:
#   Category                                            Message  spam
# 0      ham  Go until jurong point, crazy.. Available only ...     0
# 1      ham                      Ok lar... Joking wif u oni...     0
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...     1
# 3      ham  U dun say so early hor... U c already then say...     0
# 4      ham  Nah I don't think he goes to usf, he lives aro...     0

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df.Message, df.spam, test_size=0.2)

# %%
X_train.shape
# Out:
# (4457,)

# %%
X_test.shape
# Out:
# (1115,)

# %%
X_train[:4]
# Out:
# 4624                             I'm on the bus. Love you
# 4769    CHEERS LOU! YEAH WAS A GOODNITE SHAME U NEVA C...
# 993     The Xmas story is peace.. The Xmas msg is love...
# 1574    My sis is catching e show in e afternoon so i'...
# Name: Message, dtype: object

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %%
y_train[:4]
# Out:
# 4624    0
# 4769    0
# 993     0
# 1574    0
# Name: spam, dtype: int64

# %%
type(X_train.values)
# Out:
# numpy.ndarray

# %%
from sklearn.feature_extraction.text import CountVectorizer

v = CountVectorizer()

X_train_cv = v.fit_transform(X_train.values)
X_train_cv
# Out:
# <4457x7733 sparse matrix of type '<class 'numpy.int64'>'
# 	with 59372 stored elements in Compressed Sparse Row format>

# %%
X_train_cv.toarray()[:2][0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
X_train_cv.shape
# Out:
# (4457, 7733)

# %%
v.get_feature_names_out()[4931]
# Out:
# 'on'

# %%
v.vocabulary_
# Out:
# {'on': 4931,
#  'the': 6790,
#  'bus': 1579,
#  'love': 4227,
#  'you': 7685,
#  'cheers': 1783,
#  'lou': 4221,
#  'yeah': 7657,
#  'was': 7362,
#  'goodnite': 3217,
#  'shame': 6052,
#  'neva': 4749,
#  'came': 1639,
#  'ya': 7642,
#  'gailxx': 3090,
#  'xmas': 7625,
#  'story': 6492,
#  'is': 3764,
#  'peace': 5129,
#  'msg': 4613,
#  'miracle': 4504,
#  'jesus': 3837,
#  'hav': 3382,
#  'blessed': 1396,
#  'month': 4574,
#  'ahead': 877,
#  'amp': 954,
#  'wish': 7515,
#  'merry': 4454,
#  'my': 4661,
#  'sis': 6170,
#  'catching': 1702,
#  'show': 6114,
#  'in': 3662,
#  'afternoon': 859,
#  'so': 6269,
#  'not': 4829,
#  'watching': 7374,
#  'her': 3433,
#  'wan': 7344,
#  'watch': 7370,
#  'today': 6914,
#  'or': 4971,
#  'tmr': 6904,
#  'lor': 4207,
#  'can': 1643,
#  'send': 6002,
#  'pic': 5203,
#  'if': 3619,
#  'like': 4114,
#  'midnight': 4474,
#  'at': 1120,
#  'earliest': 2536,
#  'wats': 7381,
#  'ur': 7169,
#  'opinion': 4960,
#  'abt': 772,
#  'him': 3457,
#  'and': 967,
#  'how': 3540,
#  'character': 1751,
#  'yar': 7649,
#  'but': 1586,
#  'they': 6814,
#  'say': 5924,
#  'got': 3227,
#  'some': 6283,
#  'error': 2665,
#  'had': 3320,
#  'your': 7691,
#  'contract': 2014,
#  'mobile': 4540,
#  '11': 277,
#  'mnths': 4535,
#  'latest': 4035,
#  'motorola': 4594,
#  'nokia': 4805,
#  'etc': 2679,
#  'all': 917,
#  'free': 3016,
#  'double': 2448,
#  'mins': 4499,
#  'text': 6761,
#  'orange': 4975,
#  'tariffs': 6688,
#  'yes': 7668,
#  'for': 2971,
#  'callback': 1622,
#  'no': 4795,
#  'to': 6909,
#  'remove': 5696,
#  'from': 3051,
#  'records': 5639,
#  'have': 3384,
#  'take': 6667,
#  'exam': 2723,
#  'with': 7523,
#  'march': 4354,
#  'are': 1054,
#  'winner': 7506,
#  'been': 1299,
#  'specially': 6358,
#  'selected': 5990,
#  'receive': 5623,
#  '1000': 266,
#  'cash': 1690,
#  '2000': 359,
#  'award': 1172,
#  'speak': 6352,
#  'live': 4156,
#  'operator': 4959,
#  'claim': 1844,
#  'call': 1619,
#  '087123002209am': 100,
#  '7pm': 636,
#  'cost': 2044,
#  '10p': 276,
#  'tone': 6934,
#  'mob': 4538,
#  'every': 2697,
#  'week': 7410,
#  'just': 3886,
#  'txt': 7070,
#  'nok': 4804,
#  '87021': 692,
#  '1st': 347,
#  'get': 3148,
#  'txtin': 7074,
#  'now': 4844,
#  'tell': 6730,
#  'friends': 3036,
#  '150p': 314,
#  '16': 324,
#  'reply': 5716,
#  'hl': 3471,
#  '4info': 525,
#  'shall': 6051,
#  'come': 1931,
#  'pickle': 5207,
#  'me': 4404,
#  'too': 6945,
#  'baby': 1194,
#  'promise': 5455,
#  'treat': 7005,
#  'well': 7427,
#  'bet': 1336,
#  'will': 7493,
#  'good': 3211,
#  'care': 1669,
#  'of': 4892,
#  'ok': 4914,
#  'feel': 2838,
#  'john': 3852,
#  'lennon': 4080,
#  'nah': 4675,
#  'don': 2431,
#  'think': 6821,
#  'he': 3393,
#  'goes': 3195,
#  'usf': 7191,
#  'lives': 4160,
#  'around': 1076,
#  'here': 3434,
#  'though': 6840,
#  'fyi': 3084,
#  'has': 3374,
#  'ride': 5781,
#  'early': 2537,
#  'tomorrow': 6932,
#  'morning': 4584,
#  'crashing': 2086,
#  'our': 5002,
#  'place': 5232,
#  'tonight': 6941,
#  'offer': 4896,
#  '150': 312,
#  'worth': 7584,
#  'discount': 2378,
#  'vouchers': 7295,
#  '85023': 682,
#  'savamob': 5918,
#  'member': 4437,
#  'offers': 4898,
#  'cs': 2118,
#  '08717898035': 136,
#  '00': 0,
#  'sub': 6531,
#  'unsub': 7147,
#  'where': 7460,
#  'when': 7456,
#  'wil': 7489,
#  'reach': 5588,
#  'howz': 3546,
#  'that': 6784,
#  'persons': 5170,
#  'ryder': 5863,
#  'unsold': 7146,
#  'gibbs': 3160,
#  'lions': 4139,
#  'england': 2631,
#  'lionm': 4137,
#  'mono': 4570,
#  'lionp': 4138,
#  'poly': 5296,
#  'more': 4580,
#  'go': 3187,
#  'www': 7615,
#  'ringtones': 5792,
#  'co': 1896,
#  'uk': 7095,
#  'original': 4987,
#  'best': 1334,
#  'tones': 6935,
#  '3gbp': 470,
#  'network': 4746,
#  'rates': 5572,
#  'apply': 1029,
#  'oh': 4910,
#  'yah': 7643,
#  'we': 7390,
#  'never': 4750,
#  'cancel': 1647,
#  'leh': 4076,
#  'haha': 3323,
#  'went': 7433,
#  'project': 5450,
#  'centre': 1726,
#  've': 7226,
#  'told': 6924,
#  'returned': 5761,
#  'it': 3776,
#  'should': 6109,
#  're': 5587,
#  'order': 4978,
#  'cool': 2029,
#  'll': 4164,
#  'way': 7385,
#  'hows': 3545,
#  'street': 6499,
#  'end': 2617,
#  'library': 4097,
#  'walk': 7331,
#  'thanx4': 6782,
#  'cer': 1728,
#  'nice': 4767,
#  'catch': 1700,
#  'up': 7153,
#  'ave': 1161,
#  'find': 2884,
#  'time': 6878,
#  'often': 4907,
#  'soon': 6309,
#  'sorry': 6319,
#  'bed': 1294,
#  'nightnight': 4777,
#  'what': 7449,
#  'happen': 3356,
#  'truth': 7033,
#  'late': 4031,
#  'start': 6435,
#  'great': 3264,
#  'church': 1837,
#  'holla': 3491,
#  'out': 5005,
#  'private': 5423,
#  '2004': 361,
#  'account': 790,
#  'statement': 6443,
#  '07742676969': 30,
#  'shows': 6120,
#  '786': 630,
#  'unredeemed': 7144,
#  'bonus': 1431,
#  'points': 5288,
#  '08719180248': 154,
#  'identifier': 3612,
#  'code': 1907,
#  '45239': 509,
#  'expires': 2749,
#  'said': 5878,
#  'would': 7589,
#  'be': 1278,
#  'woke': 7546,
#  'sent': 6012,
#  'scores': 5941,
#  'sophas': 6315,
#  'do': 2403,
#  'secondary': 5966,
#  'application': 1028,
#  'few': 2853,
#  'schools': 5936,
#  'thinking': 6824,
#  'applying': 1031,
#  'research': 5728,
#  'also': 931,
#  'contact': 2004,
#  'joke': 3857,
#  'ogunrinde': 4909,
#  'school': 5935,
#  'one': 4936,
#  'less': 4084,
#  'expensive': 2744,
#  'ones': 4937,
#  'hello': 3421,
#  'damn': 2177,
#  'this': 6829,
#  'christmas': 1834,
#  'thing': 6819,
#  'decided': 2226,
#  'keep': 3917,
#  'mp3': 4606,
#  'doesnt': 2414,
#  'work': 7568,
#  'doesn': 2413,
#  'class': 1853,
#  'thus': 6864,
#  'shouldn': 6111,
#  'trying': 7036,
#  'smoke': 6243,
#  'lt': 4249,
#  'gt': 3290,
#  'hi': 3447,
#  'babe': 1191,
#  'its': 3782,
#  'jordan': 3866,
#  'im': 3635,
#  'home': 3494,
#  'abroad': 768,
#  'lonely': 4193,
#  'back': 1200,
#  'wanna': 7347,
#  'chat': 1763,
#  'xxsp': 7630,
#  'visionsms': 7271,
#  'com': 1927,
#  'stop': 6480,
#  'stopcost': 6482,
#  '08712400603': 104,
#  'convey': 2020,
#  'regards': 5662,
#  'btw': 1551,
#  'regarding': 5661,
#  'really': 5607,
#  'try': 7034,
#  'see': 5978,
#  'anyone': 1002,
#  'else': 2599,
#  '4th': 530,
#  'guy': 3311,
#  'before': 1304,
#  'commit': 1941,
#  'random': 5563,
#  'dude': 2511,
#  'loans': 4171,
#  'any': 998,
#  'purpose': 5506,
#  'even': 2691,
#  'bad': 1202,
#  'credit': 2094,
#  'tenants': 6740,
#  'welcome': 7425,
#  'noworriesloans': 4848,
#  '08717111821': 128,
#  'am': 940,
#  'officially': 4902,
#  'philosophical': 5185,
#  'hole': 3489,
#  'ready': 5598,
#  'saved': 5920,
#  'no1': 4796,
#  '8077': 652,
#  'txting': 7075,
#  'mates': 4379,
#  'getzed': 3156,
#  'pobox': 5270,
#  '36504': 460,
#  'w45wq': 7310,
#  'norm150p': 4820,
#  'specialisation': 6356,
#  'slave': 6200,
#  'labor': 3994,
#  'look': 4197,
#  'sha': 6042,
#  'cos': 2043,
#  'shakara': 6049,
#  'beggar': 1306,
#  'santa': 5898,
#  'calling': 1632,
#  'little': 4155,
#  'eve': 2689,
#  '09077818151': 249,
#  'book': 1434,
#  'calls1': 1634,
#  '50ppm': 548,
#  'last': 4029,
#  '3mins': 475,
#  '30s': 445,
#  'santacalling': 5899,
#  'guaranteed': 3292,
#  'phone': 5189,
#  '40gb': 492,
#  'ipod': 3754,
#  'player': 5247,
#  '500': 538,
#  'prize': 5426,
#  'word': 7566,
#  'collect': 1918,
#  '83355': 668,
#  'ibhltd': 3594,
#  'ldnw15h': 4054,
#  'mtmsgrcvd18': 4627,
#  'secret': 5968,
#  'admirer': 825,
#  'reveal': 5765,
#  'who': 7471,
#  'thinks': 6825,
#  'special': 6354,
#  '09065174042': 226,
#  'opt': 4965,
#  '50': 537,
#  'per': 5145,
#  'recd': 5620,
#  'cust': 2150,
#  '07821230901': 41,
#  'jus': 3885,
#  'finish': 2890,
#  'lunch': 4261,
#  'tot': 6965,
#  'dun': 2518,
#  'stay': 6446,
#  'sch': 5933,
#  'thats': 6787,
#  'want': 7349,
#  'please': 5251,
#  'kate': 3910,
#  'evening': 2692,
#  'hope': 3511,
#  'bit': 1376,
#  'bloody': 1411,
#  'babyjontet': 1196,
#  'xxx': 7632,
#  'refilled': 5654,
#  'successfully': 6548,
#  'by': 1600,
#  'inr': 3708,
#  'decimal': 2228,
#  'keralacircle': 3925,
#  'prepaid': 5383,
#  'balance': 1215,
#  'rs': 5838,
#  'transaction': 6989,
#  'id': 3606,
#  'kr': 3980,
#  'alright': 929,
#  'hooked': 3509,
#  'guys': 3312,
#  'both': 1451,
#  'inside': 3712,
#  'outside': 5017,
#  'bedroom': 1296,
#  'em': 2602,
#  'olowoyey': 4928,
#  'usc': 7185,
#  'edu': 2564,
#  'argentina': 1060,
#  'sad': 5872,
#  'about': 765,
#  'secretary': 5969,
#  'everything': 2706,
#  'blessing': 1397,
#  'noe': 4799,
#  'la': 3991,
#  'wana': 7346,
#  'pei': 5136,
#  'bf': 1347,
#  'oso': 4993,
#  'rite': 5798,
#  'other': 4994,
#  'days': 2205,
#  'den': 2265,
#  'xxxmobilemovieclub': 7633,
#  'use': 7186,
#  'click': 1866,
#  'wap': 7354,
#  'link': 4133,
#  'next': 4763,
#  'message': 4457,
#  'http': 3555,
#  'qjkgighjjgcbl': 5523,
#  'lar': 4024,
#  'joking': 3861,
#  'wif': 7485,
#  'oni': 4938,
#  'unni': 7142,
#  'thank': 6777,
#  'dear': 2216,
#  'recharge': 5630,
#  'rakhesh': 5556,
#  'friend': 3035,
#  'she': 6065,
#  'studying': 6521,
#  'warwick': 7361,
#  'planned': 5241,
#  'shopping': 6099,
#  'concert': 1973,
#  'tmw': 6907,
#  'may': 4396,
#  'canceled': 1648,
#  'havn': 3390,
#  'seen': 5985,
#  'ages': 870,
#  'together': 6918,
#  'sometime': 6294,
#  'except': 2726,
#  'theres': 6807,
#  'chick': 1799,
#  'huge': 3561,
#  'boobs': 1433,
#  'logo': 4184,
#  'lover': 4232,
#  'names': 4684,
#  'joined': 3855,
#  'heart': 3407,
#  'name1': 4681,
#  'name2': 4682,
#  'mobno': 4545,
#  'eg': 2576,
#  'adam': 814,
#  '07123456789': 26,
#  '87077': 695,
#  'yahoo': 7644,
#  'pobox36504w45wq': 5275,
#  'txtno': 7076,
#  'ads': 832,
#  'teach': 6709,
#  'apps': 1041,
#  'da': 2167,
#  'college': 1922,
#  'night': 4775,
#  'warm': 7355,
#  'bath': 1252,
#  'drink': 2478,
#  'cup': 2141,
#  'milk': 4481,
#  'magic': 4311,
#  'still': 6468,
#  'need': 4723,
#  'loose': 4204,
#  'weight': 7418,
#  'know': 3971,
#  'could': 2055,
#  'pick': 5204,
#  'remember': 5685,
#  'eek': 2570,
#  'lot': 4214,
#  'especially': 2673,
#  'since': 6157,
#  'american': 944,
#  'pie': 5212,
#  'minutes': 4502,
#  'long': 4194,
#  'singing': 6162,
#  '146tf150p': 309,
#  'helloooo': 3422,
#  'wake': 7327,
#  'sweet': 6633,
#  'welcomes': 7426,
#  'enjoy': 2633,
#  'day': 2204,
#  'full': 3068,
#  'joy': 3869,
#  'gud': 3294,
#  'mrng': 4610,
#  'hey': 3442,
#  'whats': 7451,
#  'sleeping': 6203,
#  'missed': 4511,
#  'cause': 1705,
#  'yelling': 7662,
#  'scrappy': 5947,
#  'miss': 4510,
#  'wait': 7323,
#  'funny': 3076,
#  'fact': 2775,
#  'nobody': 4798,
#  'teaches': 6712,
#  'volcanoes': 7287,
#  'erupt': 2669,
#  'tsunamis': 7043,
#  'arise': 1066,
#  'hurricanes': 3576,
#  'sway': 6628,
#  'aroundn': 1077,
#  'hw': 3588,
#  'choose': 1825,
#  'wife': 7486,
#  'natural': 4703,
#  'disasters': 2372,
#  'happens': 3361,
#  'delhi': 2255,
#  'chennai': 1788,
#  'silent': 6146,
#  'hoping': 3516,
#  'rent': 5701,
#  'due': 2514,
#  'dont': 2435,
#  'enough': 2639,
#  'reserves': 5733,
#  'completely': 1958,
#  'gone': 3207,
#  'loan': 4170,
#  'there': 6806,
#  'till': 6877,
#  'mid': 4472,
#  'pay': 5116,
#  'saw': 5923,
#  'lasting': 4030,
#  'as': 1091,
#  'much': 4631,
#  'hours': 3534,
#  'might': 4476,
#  'lucky': 4255,
#  'usually': 7196,
#  'person': 5165,
#  'unconscious': 7112,
#  'children': 1807,
#  'adults': 835,
#  'behave': 1312,
#  'abnormally': 764,
#  'cold': 1914,
#  'ill': 3632,
#  'company': 1948,
#  'ta': 6657,
#  'daaaaa': 2168,
#  'becoz': 1292,
#  'jan': 3808,
#  'whn': 7470,
#  'al': 899,
#  'post': 5331,
#  'ofice': 4904,
#  'holiday': 3490,
#  'cn': 1892,
#  'fr': 3005,
#  'duffer': 2515,
#  'ask': 1098,
#  'iouri': 3748,
#  'ten': 6739,
#  'times': 6879,
#  'already': 928,
#  'actually': 812,
#  'getting': 3155,
#  'leave': 4065,
#  'house': 3535,
#  'later': 4034,
#  'gas': 3111,
#  'money': 4565,
#  'chance': 1741,
#  'gang': 3102,
#  'grand': 3248,
#  'nature': 4704,
#  'adventure': 837,
#  'thanx': 6781,
#  'birthday': 1374,
#  'over': 5022,
#  'starshine': 6434,
#  'boytoy': 1484,
#  'does': 2411,
#  'crave': 2087,
#  'yet': 7671,
#  'ache': 795,
#  'fuck': 3058,
#  'sips': 6168,
#  'cappuccino': 1661,
#  'teasing': 6719,
#  'kiss': 3958,
#  'ummmmmaah': 7103,
#  'many': 4351,
#  'happy': 3366,
#  'returns': 5763,
#  'pin': 5220,
#  'god': 3193,
#  'limit': 4122,
#  'grace': 3243,
#  'measure': 4414,
#  'power': 5348,
#  'boundaries': 1458,
#  'endless': 2620,
#  'blessings': 1398,
#  'always': 938,
#  'life': 4103,
#  'ni8': 4765,
#  'probably': 5431,
#  'while': 7466,
#  'remains': 5684,
#  'bro': 1527,
#  'amongst': 952,
#  'bros': 1533,
#  'usual': 7195,
#  'ard': 1053,
#  '10': 264,
#  'smth': 6254,
#  'hamster': 3339,
#  'dead': 2211,
#  'meet': 4422,
#  '1pm': 346,
#  'orchard': 4977,
#  'mrt': 4611,
#  'kay': 3913,
#  'someone': 6287,
#  'make': 4326,
#  'them': 6797,
#  'loved': 4228,
#  'nit': 4788,
#  'party': 5093,
#  'charge': 1753,
#  'contribute': 2015,
#  'greatly': 3266,
#  'appreciated': 1035,
#  'room': 5818,
#  'charges': 1755,
#  'after': 857,
#  'transfer': 6991,
#  'withdraw': 7524,
#  'anyhow': 1000,
#  'again': 863,
#  'scream': 5950,
#  'moan': 4537,
#  'princess': 5414,
#  'luton': 4263,
#  '0125698789': 7,
#  'ring': 5787,
#  'raji': 5555,
#  'pls': 5259,
#  'favour': 2827,
#  'wishes': 7517,
#  'nimya': 4784,
#  'scratching': 5949,
#  'kidding': 3941,
#  'papa': 5069,
#  'needs': 4728,
#  'drugs': 2496,
#  'urgent': 7173,
#  '2nd': 415,
#  'attempt': 1130,
#  '900': 726,
#  'yesterday': 7670,
#  'awaiting': 1170,
#  'collection': 1921,
#  '09061702893': 201,
#  'face': 2772,
#  'test': 6757,
#  'select': 5989,
#  'number': 4858,
#  'astrology': 1116,
#  'waiting': 7326,
#  'quick': 5532,
#  'accept': 781,
#  'brother': 1536,
#  'sister': 6171,
#  'dear1': 2217,
#  'best1': 1335,
#  'clos1': 1871,
#  'lvblefrnd': 4270,
#  'jstfrnd': 3874,
#  'cutefrnd': 2159,
#  'lifpartnr': 4106,
#  'belovd': 1324,
#  'swtheart': 6646,
#  'bstfrnd': 1549,
#  'rply': 5836,
#  'means': 4411,
#  'enemy': 2624,
#  'expect': 2740,
#  'whenever': 7457,
#  'tomo': 6930,
#  'important': 3651,
#  'information': 3694,
#  'o2': 4876,
#  'user': 7189,
#  'why': 7478,
#  'log': 4180,
#  'onto': 4944,
#  'urawinner': 7170,
#  'fantastic': 2807,
#  'surprise': 6612,
#  'texting': 6769,
#  'right': 5782,
#  'gonna': 3209,
#  'ticket': 6868,
#  'mallika': 4335,
#  'sherawat': 6071,
#  'did': 2326,
#  'url': 7179,
#  'hiya': 3470,
#  'didn': 2328,
#  'signal': 6140,
#  'haven': 3385,
#  'heard': 3405,
#  'neither': 4736,
#  'which': 7465,
#  'unusual': 7152,
#  'itself': 3783,
#  'put': 5512,
#  'case': 1689,
#  'sort': 6320,
#  'hugs': 3562,
#  'snogs': 6262,
#  'confirmed': 1984,
#  'staying': 6449,
#  'weekend': 7412,
#  'same': 5892,
#  'indians': 3686,
#  'poor': 5309,
#  'india': 3684,
#  'country': 2060,
#  'says': 5927,
#  'swiss': 6642,
#  'bank': 1227,
#  'directors': 2364,
#  'lac': 3995,
#  'crore': 2106,
#  'indian': 3685,
#  'deposited': 2278,
#  'banks': 1228,
#  'used': 7187,
#  'taxless': 6700,
#  'budget': 1557,
#  'yrs': 7701,
#  'give': 3173,
#  'jobs': 3849,
#  'village': 7260,
#  'lane': 4016,
#  'roads': 5801,
#  'forever': 2976,
#  'suply': 6593,
#  'than': 6775,
#  'social': 6271,
#  'projects': 5451,
#  'citizen': 1841,
#  'monthly': 4575,
#  'world': 7575,
#  'imf': 3641,
#  'blocked': 1402,
#  'rich': 5778,
#  'politicians': 5294,
#  'rights': 5785,
#  'against': 864,
#  'corrupt': 2041,
#  'itna': 3781,
#  'forward': 2994,
#  'karo': 3909,
#  'ki': 3935,
#  'pura': 5500,
#  'padhe': 5049,
#  'lmao': 4166,
#  'rgent': 5775,
#  'won': 7551,
#  '1250': 293,
#  '09071512433': 247,
#  'b4': 1184,
#  '050703': 18,
#  'csbcm4235wc1n3xx': 2119,
#  'callcost': 1623,
#  '150ppm': 318,
#  'mobilesvary': 4543,
#  'maxå': 4395,
#  'ìï': 7724,
#  'until': 7151,
#  'dat': 2196,
#  'buy': 1591,
#  'ericsson': 2661,
#  'cannot': 1654,
#  'oredi': 4981,
#  'okay': 4915,
#  'thought': 6841,
#  'were': 7436,
#  'expert': 2747,
#  'storming': 6491,
#  'wen': 7430,
#  'lift': 4107,
#  'phne': 5187,
#  'knw': 3975,
#  'wt': 7607,
#  'real': 5599,
#  'meaning': 4408,
#  'name': 4680,
#  'girl': 3167,
#  'margaret': 4356,
#  'girlfrnd': 3168,
#  'grahmbell': 3245,
#  'invnted': 3746,
#  'telphone': 6734,
#  'moral': 4579,
#  '4get': 523,
#  'thinl': 6827,
#  'role': 5811,
#  'sachin': 5868,
#  'standing': 6427,
#  'others': 4995,
#  'hit': 3465,
#  'tuition': 7049,
#  '330': 455,
#  'hm': 3474,
#  '1120': 278,
#  '1205': 288,
#  'mind': 4487,
#  'then': 6801,
#  'pa': 5043,
#  'ru': 5843,
#  'uncle': 7109,
#  'boye': 1480,
#  'movies': 4603,
#  'guide': 3303,
#  'plus': 5264,
#  'torrents': 6960,
#  'particularly': 5089,
#  'legal': 4073,
#  'system': 6654,
#  'slowing': 6220,
#  'down': 2455,
#  'gr8': 3240,
#  'started': 6436,
#  'online': 4940,
#  'honey': 3500,
#  'moon': 4578,
#  'reminder': 5692,
#  'wonderful': 7554,
#  'imma': 3644,
#  'flip': 2926,
#  'shit': 6085,
#  'half': 3331,
#  'an': 962,
#  'hour': 3532,
#  'mail': 4319,
#  'relatives': 5673,
#  'coming': 1937,
#  'deliver': 2257,
#  'costs': 2047,
#  'risks': 5797,
#  'benefits': 1331,
#  'anything': 1005,
#  'thanks': 6778,
#  'check': 1773,
#  'rooms': 5822,
#  'befor': 1303,
#  'activities': 809,
#  'rose': 5824,
#  'red': 5644,
#  'blood': 1410,
#  'tis': 6889,
#  'including': 3671,
#  'relation': 5671,
#  'support': 6598,
#  'frnd': 3043,
#  'some1': 6284,
#  'luvs': 4266,
#  'praying': 5371,
#  'marry': 4365,
#  'na': 4670,
#  'whore': 7474,
#  'unbelievable': 7106,
#  'tough': 6971,
#  'married': 4364,
#  'local': 4173,
#  'women': 7550,
#  'looking': 4201,
#  'discreet': 2379,
#  'action': 805,
#  'matches': 4377,
#  'instantly': 3719,
#  'match': 4376,
#  '69969': 602,
#  'bcmsfwc1n3xx': 1272,
#  'tel': 6726,
#  'software': 6274,
#  'search': 5961,
#  'hard': 3367,
#  'let': 4088,
#  'wnt': 7544,
#  'bmw': 1422,
#  'car': 1665,
#  'urgently': 7174,
#  'vry': 7297,
#  'hv': 3585,
#  'shortage': 6103,
#  'lacs': 3997,
#  'source': 6334,
#  'arng': 1073,
#  'dis': 2367,
#  'amt': 959,
#  'prob': 5430,
#  'fetch': 2851,
#  'yun': 7704,
#  'someonone': 6288,
#  'via': 7243,
#  'dating': 2201,
#  'service': 6024,
#  'landline': 4011,
#  '09064015307': 217,
#  'box334sk38ch': 1469,
#  ...}

# %%
X_train_np = X_train_cv.toarray()
X_train_np[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
np.where(X_train_np[0]!=0)
# Out:
# (array([1579, 4227, 4931, 6790, 7685], dtype=int64),)

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()
model.fit(X_train_cv, y_train)
# Out:
# MultinomialNB()

# %%
X_test_cv = v.transform(X_test)

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(X_test_cv)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       963
#            1       0.97      0.92      0.95       152
#
#     accuracy                           0.99      1115
#    macro avg       0.98      0.96      0.97      1115
# weighted avg       0.99      0.99      0.99      1115

# %%
emails = [
    'Hey mohan, can we get together to watch footbal game tomorrow?',
    'Upto 20% discount on parking, exclusive offer just for you. Dont miss this reward!'
]

emails_count = v.transform(emails)
model.predict(emails_count)
# Out:
# array([0, 1], dtype=int64)

# %%
from sklearn.pipeline import Pipeline

clf = Pipeline([
    ('vectorizer', CountVectorizer()),
    ('nb', MultinomialNB())
])

# %%
clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer()), ('nb', MultinomialNB())])

# %%
y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       963
#            1       0.97      0.92      0.95       152
#
#     accuracy                           0.99      1115
#    macro avg       0.98      0.96      0.97      1115
# weighted avg       0.99      0.99      0.99      1115
